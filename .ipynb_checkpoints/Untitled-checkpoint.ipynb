# %%
url = 'https://news.google.com/search?q=%E9%81%B8%E8%88%89&hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant'

r = requests.get(url) #抓取網址
web_content = r.text #網址的text
soup = BeautifulSoup(web_content, 'lxml')
# Out:
# '<!doctype html><html lang="zh" dir="ltr"><head><base href="https://news.google.com/"><meta name="referrer" content="origin"><link rel="canonical" href="https://news.google.com/search"><meta name="viewport" content="width=device-width,initial-scale=1,minimal-ui"><meta name="google-site-verification" content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="application-name" content="新聞"><meta name="apple-mobile-web-app-title" content="新聞"><meta name="apple-mobile-web-app-status-bar-style" content="black"><meta name="theme-color" content="white"><meta name="msapplication-tap-highlight" content="no"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" sizes="16x16"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import scrapy
import re

# %%
title = soup.find_all('div', class_ = 'xrnccd') # xrnccd Google新聞的分隔區
print(title)
# Out:
# [<div class="xrnccd"><article class="MQsxIb xTewfe R7GTQ keNKEd j7vNaf Cc0Z5d EjqUne" data-kind="13" data-n-cvid="i5" data-n-et="107" data-n-ham="true" data-n-vlb="0" jsaction=";rcuQ6b:npT2md; click:KjsqPd;EXlHgb:HQ4Dqd" jscontroller="mhFxVb" jsdata="oM6qxc;CBMiMmh0dHBzOi8vd3d3LmNuYS5jb20udHcvbmV3cy9haGVsLzIwMjAwNjE4MDA4OS5hc3B40gE2aHR0cHM6Ly93d3cuY25hLmNvbS50dy9hbXAvbmV3cy9haGVsLzIwMjAwNjE4MDA4OS5hc3B4;4" jslog="85008" jsmodel="QWGJif hT8rr"><a aria-hidden="true" class="VDXfz" href="./articles/CBMiMmh0dHBzOi8vd3d3LmNuYS5jb20udHcvbmV3cy9haGVsLzIwMjAwNjE4MDA4OS5hc3B40gE2aHR0cHM6Ly93d3cuY25hLmNvbS50dy9hbXAvbmV3cy9haGVsLzIwMjAwNjE4MDA4OS5hc3B4?hl=zh-TW&amp;gl=TW&amp;ceid=TW%3Azh-Hant" jslog="95014; 5:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCwiaHR0cHM6Ly93d3cuY25hLmNvbS50dy9uZXdzL2FoZWwvMjAyMDA2MTgwMDg5LmFzcHgiXQ==; track:click" jsname="hXwDdf" tabindex="-1" target="_blank"></a><h3 class="ipQwMb ekueJc gEATFF RD0gLb"><a class="DY5T1d" href="./articles/CBMiMmh0dHBzOi8vd3d3LmN
# ...

# %%
titles = [t.find('span').text for t in title]
titles
# Out:
# ['日期：2020年06月17日公司名稱：國票金(2889)主旨：國票金第七屆董事會選舉董事長、副董事長發言人：邱銘恩說明：1.董事會決議日期或發生變動日期:109/06/172.',
#  '美國民主黨總統候選人拜登陣營今天表示，拜登競選團隊和民主黨全國委員會今年5月一同募得8080萬美元（新台幣24億2400萬元），創下競選活動單月募款最佳 ...',
#  '高雄中學學生聯合自治會因為會長、副會長當選人疑有賄選之嫌公告「當選無效」並擇訂18日重新選舉，不過，今天學聯會自治會再公告因被處分人已提出申訴，將延後 ...',
#  '日期：2020年06月16日公司名稱：嘉聯益(6153)主旨：嘉聯益109年股東常會全面改選董事選舉結果發言人：王吉輝說明：1.發生變動日期:109/06/162.選任或變動人員 ...',
#  '在現代民主社會，所謂的官商勾結，大抵體現於財閥於政治選舉中大灑金錢，令政客在各社會政策立場向自身利益傾斜。政客與商家這樣的依存關係，好聽的，是政治 ...',
#  '匯流新聞網記者邱璽臣／台北報導. 從去年韓國瑜參選總統到罷韓事件之後，「帶職參選」一直是外界檢討的焦點，時代力量黨主席徐永明多次表態應修法禁帶職參選， ...',
#  '高雄中學學生聯合自治會會長、副會長選舉5月28日投票，但有學生以當選人涉及賄選、損及當選正當性提出異議。學聯會選舉委員會...',
#  '高雄市長補選在即，民進黨好整以暇，國民黨則陷入人選難覓的窘境，甚至眼見韓國瑜遭到「高票罷免」，為避免大花資源又吃力不討好，國民黨更一度對.',
#  '民進黨7月19日將召開全代會，改選權力核心中常會；中執委選舉明天起至19日辦理領表登記；黨內人士觀察，目前正國會應可穩住2席、新系力拚保3、海派要搶2席， ...',
#  '日期：2020年06月15日公司名稱：德記(5902)主旨：德記109年股東常會選舉第11屆董事(含獨立董事)全面改選相關訊息發言人：許娟娟說明：1.發生變動 ...',
#  '比爾蓋茲夫婦經常前往低收入國家，第一線了解在地的公衛問題。他當時並未料到，對於「能源貧窮」的關注，會成為日後研究氣候變遷的開端。如今，當地球愈來愈逼近 ...',
# ...

# %%
news_url = [requests.get(t.find('a')['href'].replace('.', 'https://news.google.com',1)).url for t in title]
news_url
# Out:
# ['https://tw.stock.yahoo.com/news/%E5%85%AC%E5%91%8A-%E5%9C%8B%E7%A5%A8%E9%87%91%E7%AC%AC%E4%B8%83%E5%B1%86%E8%91%A3%E4%BA%8B%E6%9C%83%E9%81%B8%E8%88%89%E8%91%A3%E4%BA%8B%E9%95%B7-%E5%89%AF%E8%91%A3%E4%BA%8B%E9%95%B7-073815595.html',
#  'https://www.cna.com.tw/news/aopl/202006160308.aspx',
#  'https://money.udn.com/money/story/5648/4641290',
#  'https://tw.stock.yahoo.com/news/%E5%85%AC%E5%91%8A-%E5%98%89%E8%81%AF%E7%9B%8A109%E5%B9%B4%E8%82%A1%E6%9D%B1%E5%B8%B8%E6%9C%83%E5%85%A8%E9%9D%A2%E6%94%B9%E9%81%B8%E8%91%A3%E4%BA%8B%E9%81%B8%E8%88%89%E7%B5%90%E6%9E%9C-101922550.html',
#  'https://news.mingpao.com/ins/%E6%96%87%E6%91%98/article/20200617/s00022/1592313535134/%E6%94%BF%E6%B2%BB%E6%8D%90%E7%8D%BB%E5%A6%82%E4%BD%95%E6%93%8D%E6%8E%A7%E7%BE%8E%E5%9C%8B%E9%81%B8%E8%88%89%EF%BC%88%E6%96%87-%E5%8A%89%E6%85%A7%E5%90%9B%EF%BC%89',
#  'https://news.sina.com.tw/article/20200617/35496122.html',
#  'https://udn.com/news/story/6885/4634588',
# ...

# %%
# create data frame 
df = pd.DataFrame(
{
    'title' : titles,
    'links' : news_url
})

df.to_csv('/Users/garday/Documents/MY499/Data Collection/Data/news_選舉.csv')

# %%
url = 'https://tw.appledaily.com/search/result?sort=time&searchType=all&dateStart=2011%2F11%2F04&dateEnd=2012%2F01%2F13&querystrS=%E9%A6%AC%E8%8B%B1%E4%B9%9D'

r = requests.get(url) #抓取網址
web_content = r.text #網址的text
soup = BeautifulSoup(web_content, 'lxml')

# %%
title = soup.find_all('div', class_ = 'content') # xrnccd Google新聞的分隔區
#print(title)
headers = [t.find('a').text for t in title]
#print(titles)
headers = [' '.join(t.strip()) for t in headers]
headers
# Out:
# ['馬 英 九 批 民 進 黨 政 府 \u3000 貪 污 「 歷 史 上 罕 見 」',
#  '黃 俊 雄 攜 史 艷 文 ： 選 馬 英 九 當 「 天 下 領 導 者 」',
#  '選 前 之 夜 \u3000 馬 英 九 喊 經 濟 \u3000 蔡 英 文 提 輪 替',
#  '台 灣 投 票 選 總 統 \u3000 中 國 網 友 羨 慕',
#  '連 戰 「 失 聲 」 喊 話 \u3000 為 馬 英 九 衝 刺',
#  '若 蔡 英 文 落 選 \u3000 王 世 堅 : 我 去 高 空 彈 跳',
#  '郝 龍 斌 批 綠 不 合 作 \u3000 「 花 博 」 差 點 辦 不 成',
#  '蘇 嘉 全 痛 批 馬 英 九 ： 操 作 國 家 機 器',
#  '馬 英 九 高 雄 呼 籲 \u3000 「 泛 藍 大 團 結 ， 共 創 新 紀 元 」',
#  '蘇 貞 昌 桃 園 批 馬 英 九 ： 執 政 不 佳 應 下 台']

# %%
# extract url from title
test = [t.find('a') for t in title]
for t in test:
    href = t.get('href')
    print(href)
    
len(href)
# Out:
# https://tw.appledaily.com/politics/realtime/20120113/105668/
# https://tw.appledaily.com/politics/realtime/20120113/105652/
# https://tw.appledaily.com/politics/realtime/20120113/105641/
# https://tw.appledaily.com/international/realtime/20120113/105644/
# https://tw.appledaily.com/politics/realtime/20120113/105640/
# https://tw.appledaily.com/politics/realtime/20120113/105639/
# https://tw.appledaily.com/politics/realtime/20120113/105636/
# https://tw.appledaily.com/politics/realtime/20120113/105635/
# https://tw.appledaily.com/politics/realtime/20120113/105632/
# https://tw.appledaily.com/politics/realtime/20120113/105630/
# 60

# %%
soup.find_all('a', href = True)
# Out:
# [<a class="ndgWorldbox_Location current" href="https://tw.appledaily.com" id="TwIndex">台灣</a>,
#  <a class="ndgWorldbox_Location" href="http://hk.apple.nextmedia.com" target="_blank">香港</a>,
#  <a class="ndgWorldbox_Location" href="https://us.appledaily.com/?utm_source=twad_web&amp;utm_medium=internal&amp;utm_campaign=twad_regular_entry&amp;utm_content=region_selector" target="_blank">北美</a>,
#  <a href="https://www.nextdigital.com.hk/investor/" target="_blank"><img src="//img.appledaily.com.tw/pay/img/nextdigital_logo.svg"/></a>,
#  <a href="https://tw.appledaily.com/charity">蘋果日報慈善基金會</a>,
#  <a href="https://tw.appledaily.com/" style="color:#ffffff;">台灣</a>,
#  <a href="http://hk.apple.nextmedia.com" style="color:#ffffff;" target="_blank">香港</a>,
#  <a href="https://us.appledaily.com/?utm_source=twad_web&amp;utm_medium=internal&amp;utm_campaign=twad_regular_entry&amp;utm_content=region_selector" style="color:#ffffff;" target="_blank">北美</a>,
# ...
